# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load the data
file_path = 'C:\\Users\\saive\\OneDrive\\Desktop\\Boot camp\\Loan project\\processed_loan_data.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())

# Summary statistics
print("\nSummary statistics:")
print(data.describe())

# Univariate analysis examples

# Example 1: Histogram of Loan Amount Request (USD)
plt.figure(figsize=(10, 6))
sns.histplot(data['Loan Amount Request (USD)'], bins=20, kde=True, color='blue', edgecolor='black')
plt.title('Distribution of Loan Amount Request (USD)')
plt.xlabel('Loan Amount Request (USD)')
plt.ylabel('Count')
plt.show()

# Example 2: Box plot of Income (USD)
plt.figure(figsize=(8, 5))
sns.boxplot(data['Income (USD)'])
plt.title('Box plot of Income (USD)')
plt.xlabel('Income (USD)')
plt.show()

# Example 3: Probability plot (Q-Q plot) of Credit Score
plt.figure(figsize=(8, 5))
stats.probplot(data['Credit Score'], dist="norm", plot=plt)
plt.title('Q-Q plot of Credit Score')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Ordered Values')
plt.show()
# Out:
# First few rows of the dataset:
#   Customer ID              Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995  Frederica Shealy      F   56       1933.05              Low
# 1     C-23855  Nathalie Olivier      M   43       2361.56              Low
# 2     C-24944    Barbie Goetsch      M   18       1546.17              Low
# 3     C-40801      Laree Staton      M   18       2416.86              Low
# 4     C-30073        Brinda Vaz      F   48        777.25              Low
#
#       Profession Type of Employment    Location  Loan Amount Request (USD)  \
# 0        Working        Sales staff  Semi-Urban                   72809.58
# 1        Working           Laborers  Semi-Urban                  152561.34
# 2        Working           Laborers       Rural                   42091.29
# 3  State servant         Core staff  Semi-Urban                   25765.72
# 4        Working           Laborers  Semi-Urban                   96080.60
#
# ...
